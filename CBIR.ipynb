# %% [markdown]
# # Spirit Label CBIR - BiBirra Clone

# %%
# import necessary packages
import urllib
import os
import time
import shutil
import numpy as np
import cv2
import pandas as pd

# %%
orb = cv2.ORB_create(nfeatures=5000)

img_spirit = [file for file in os.listdir('referenceImages/') if file.endswith('.png')]
# img_spirit = np.random.choice(img_spirit, len(img_spirit))

df = pd.DataFrame()
for image in img_spirit:
    img = cv2.imread("referenceImages/"+image, cv2.IMREAD_UNCHANGED)
    keypoints, desc = orb.detectAndCompute(img, None)
    df1 = pd.DataFrame({image: {"keypoints" : keypoints, "descriptor": desc }})
    df = pd.concat([df, df1], axis=1)

# %%
spirits_db = df.T
spirits_db
# Out:
#                                                                                            descriptor  \
# belle-meade-bourbon-[size].png                      [[129, 130, 27, 185, 108, 139, 232, 94, 86, 49...
# jean-fillioux-cep-d-or-[size].png                   [[13, 235, 215, 255, 242, 143, 175, 252, 62, 1...
# jim-beam-signature-craft-11-year-soft-red-wheat...  [[213, 193, 63, 104, 137, 140, 68, 140, 239, 8...
# basil-haydens-rye-[size].png                        [[66, 10, 243, 157, 37, 240, 88, 3, 79, 69, 10...
# Iwai_traditional_blended_whisky.png                 [[67, 34, 152, 241, 96, 136, 169, 6, 174, 57, ...
# foursquare-barbados-12-year-2005-[size].png         [[7, 40, 181, 177, 236, 128, 168, 19, 234, 153...
# siete-leguas-anejo-highlands-[size].png             [[193, 120, 145, 101, 32, 12, 39, 16, 106, 168...
# pasquet-coeur-de-grande-champagne-[size].png        [[18, 28, 54, 139, 29, 247, 146, 238, 141, 65,...
# absolut-mandrin-[size].png                          [[25, 77, 109, 171, 180, 130, 79, 55, 4, 224, ...
# jameson-irish-whiskey-[size].png                    [[94, 223, 210, 226, 227, 97, 126, 212, 35, 34...
# paul-beau-vsop-grande-champagne-[size].png          [[247, 59, 202, 164, 242, 166, 122, 81, 57, 20...
# barbancourt-15-year-estate-reserve-[size].png       [[66, 179, 217, 163, 242, 40, 185, 31, 42, 241...
# arart-brandy-3-year-[size].png                      [[247, 116, 213, 198, 75, 118, 27, 216, 19, 24...
# barbancourt-4-year-[size].png                       [[110, 38, 202, 163, 196, 36, 232, 82, 59, 135...
# siembra-valles-anejo-[size].png                     [[113, 48, 41, 40, 12, 77, 65, 80, 102, 108, 2...
# Ohishi Brandy Cask Whisky-750ml.png                 [[0, 148, 249, 224, 218, 77, 53, 219, 142, 241...
# talisker-18-year-single-malt-scotch-[size].png      [[3, 203, 67, 141, 118, 147, 239, 119, 29, 69,...
# jack-daniels-single-barrel-[size].png               [[28, 207, 182, 179, 151, 42, 183, 183, 30, 55...
# ledaig-18-year-[size].png                           [[112, 140, 198, 238, 28, 130, 66, 248, 151, 1...
# The Macallan Fine Oak 10 Years Old.png              [[184, 141, 106, 254, 212, 163, 198, 247, 213,...
# amaro-nonino-quintessentia-[size].png               [[67, 178, 248, 216, 108, 20, 153, 26, 43, 89,...
# makers-mark-whiskey-[size].png                      [[96, 24, 90, 237, 118, 138, 248, 73, 234, 20,...
# dalmore-25-year-old-single-malt-[size].png          [[103, 201, 106, 74, 244, 212, 235, 248, 105, ...
# isle-of-jura-single-malt-scotch-whisky-10-year-...  [[246, 167, 197, 7, 156, 59, 142, 169, 151, 19...
# boondocks-8-year-[size].png                         [[7, 51, 145, 137, 226, 33, 172, 91, 46, 242, ...
# SMIRNOFF_NO._21_RED_VODKA_80PF_750ML.png            [[88, 154, 236, 255, 170, 2, 189, 158, 38, 209...
# redbreast-irish-whiskey-12-year.png                 [[219, 95, 111, 101, 54, 86, 95, 54, 229, 204,...
# pierre-ferrand-selection-des-anges-[size].png       [[225, 121, 58, 62, 125, 141, 211, 32, 234, 20...
# Glenfarclas-25.png                                  [[246, 52, 187, 172, 250, 101, 147, 250, 139, ...
# jim-beam-rye-[size].png                             [[48, 16, 108, 101, 48, 110, 209, 52, 52, 237,...
# ...                                                                                               ...
# tomatin-12-year-french-oak-single-malt-[size].png   [[112, 48, 27, 232, 73, 77, 17, 72, 175, 32, 1...
# bodegas-tradicion-brandy-de-jerez-solera-gran-r...  [[29, 237, 187, 239, 188, 143, 127, 253, 127, ...
# el-tesoro-80th-anniversary-extra-anejo-[size].png   [[50, 107, 83, 129, 148, 74, 239, 196, 169, 37...
# jack-daniels-gentleman-jack-[size].png              [[75, 186, 122, 108, 115, 213, 187, 95, 63, 77...
# dalmore-port-wood-reserve-[size].png                [[210, 216, 124, 220, 111, 213, 188, 239, 207,...
# ciroc-vs-brandy-[size].png                          [[33, 48, 37, 65, 77, 95, 225, 16, 100, 96, 22...
# johnnie-walker-18-year-[size].png                   [[50, 48, 19, 232, 11, 73, 145, 72, 175, 36, 1...
# hillrock-estate-distillery-solera-aged-bourbon-...  [[90, 227, 227, 161, 253, 88, 234, 205, 43, 23...
# kings-county-bottled-in-bond-[size].png             [[105, 16, 216, 236, 121, 7, 89, 27, 19, 105, ...
# Highland Park 25 Year Old.png                       [[4, 164, 64, 131, 220, 41, 232, 73, 63, 49, 1...
# wild-turkey-single-barrel-kentucky-spirit-[size...  [[246, 122, 248, 198, 109, 89, 220, 212, 25, 2...
# michters-us-1-rye-[size].png                        [[2, 218, 30, 191, 51, 192, 56, 103, 172, 93, ...
# jeffersons-pritchard-hill-[size].png                [[183, 177, 225, 77, 219, 31, 147, 219, 83, 23...
# old-grand-dad-bourbon-[size].png                    [[88, 169, 58, 112, 59, 216, 49, 71, 169, 13, ...
# Hardy Organic VSOP Cognac.png                       [[79, 160, 248, 95, 138, 121, 253, 152, 115, 2...
# los-nahuales-anejo-[size].png                       [[167, 228, 97, 192, 229, 29, 238, 222, 91, 25...
# woodford-reserve-master-s-collection-oat-grain-...  [[106, 34, 247, 220, 41, 67, 89, 24, 159, 188,...
# pierre-ferrand-ancestrale-[size].png                [[56, 58, 59, 186, 13, 205, 81, 80, 171, 28, 1...
# johnnie-walker-green-label-[size].png               [[100, 48, 145, 99, 193, 109, 103, 136, 106, 2...
# deanston-14-years-limited-release-[size].png        [[80, 160, 134, 157, 29, 71, 33, 232, 182, 180...
# arette-gran-clase-extra-anejo-[size].png            [[50, 137, 202, 174, 69, 80, 206, 97, 3, 192, ...
# four-roses-small-batch-select-[size].png            [[161, 61, 24, 72, 248, 127, 215, 94, 86, 168,...
# omar-single-malt-bourbon-cask-[size].png            [[61, 132, 46, 161, 205, 107, 229, 235, 68, 11...
# isle-of-jura-seven-woods-[size].png                 [[25, 5, 236, 229, 166, 58, 93, 54, 117, 231, ...
# rebel-yell-single-barrel-[size].png                 [[170, 184, 225, 80, 207, 249, 177, 79, 219, 2...
# crown-royal-blenders-mash-[size].png                [[95, 127, 221, 164, 170, 30, 30, 61, 168, 226...
# prunier-family-reserve-[size].png                   [[102, 78, 13, 210, 120, 249, 72, 166, 143, 24...
# hine-h-by-hine-fine-champagne-[size].png            [[1, 32, 125, 97, 36, 10, 105, 16, 125, 64, 11...
# don-julio-blanco-tequila-[size].png                 [[55, 21, 239, 207, 214, 118, 177, 81, 4, 73, ...
# clement-6-year-[size].png                           [[162, 149, 62, 254, 239, 64, 180, 105, 136, 2...
#
#                                                                                             keypoints
# belle-meade-bourbon-[size].png                      [<KeyPoint 0x7fb07db2c030>, <KeyPoint 0x7fb07d...
# jean-fillioux-cep-d-or-[size].png                   [<KeyPoint 0x7fb07db2c7e0>, <KeyPoint 0x7fb07d...
# jim-beam-signature-craft-11-year-soft-red-wheat...  [<KeyPoint 0x7fb07da93bd0>, <KeyPoint 0x7fb07d...
# basil-haydens-rye-[size].png                        [<KeyPoint 0x7fb07e043450>, <KeyPoint 0x7fb07e...
# Iwai_traditional_blended_whisky.png                 [<KeyPoint 0x7fb07f566c90>, <KeyPoint 0x7fb07f...
# foursquare-barbados-12-year-2005-[size].png         [<KeyPoint 0x7fb07fb08510>, <KeyPoint 0x7fb07f...
# siete-leguas-anejo-highlands-[size].png             [<KeyPoint 0x7fb080ac2d50>, <KeyPoint 0x7fb080...
# pasquet-coeur-de-grande-champagne-[size].png        [<KeyPoint 0x7fb0815fe5d0>, <KeyPoint 0x7fb081...
# absolut-mandrin-[size].png                          [<KeyPoint 0x7fb08491ee10>, <KeyPoint 0x7fb084...
# jameson-irish-whiskey-[size].png                    [<KeyPoint 0x7fb0904bc690>, <KeyPoint 0x7fb090...
# paul-beau-vsop-grande-champagne-[size].png          [<KeyPoint 0x7fb08f90bed0>, <KeyPoint 0x7fb08f...
# barbancourt-15-year-estate-reserve-[size].png       [<KeyPoint 0x7fb08faaa750>, <KeyPoint 0x7fb08f...
# arart-brandy-3-year-[size].png                      [<KeyPoint 0x7fb08fcddf90>, <KeyPoint 0x7fb08f...
# barbancourt-4-year-[size].png                       [<KeyPoint 0x7fb08feac810>, <KeyPoint 0x7fb08f...
# siembra-valles-anejo-[size].png                     [<KeyPoint 0x7fb0900f2090>, <KeyPoint 0x7fb090...
# Ohishi Brandy Cask Whisky-750ml.png                 [<KeyPoint 0x7fb0902b48d0>, <KeyPoint 0x7fb090...
# talisker-18-year-single-malt-scotch-[size].png      [<KeyPoint 0x7fb09063f300>, <KeyPoint 0x7fb090...
# jack-daniels-single-barrel-[size].png               [<KeyPoint 0x7fb09063b990>, <KeyPoint 0x7fb090...
# ledaig-18-year-[size].png                           [<KeyPoint 0x7fb09089c210>, <KeyPoint 0x7fb090...
# The Macallan Fine Oak 10 Years Old.png              [<KeyPoint 0x7fb090a5ca50>, <KeyPoint 0x7fb090...
# amaro-nonino-quintessentia-[size].png               [<KeyPoint 0x7fb090bf0ab0>, <KeyPoint 0x7fb090...
# makers-mark-whiskey-[size].png                      [<KeyPoint 0x7fb090c76330>, <KeyPoint 0x7fb090...
# dalmore-25-year-old-single-malt-[size].png          [<KeyPoint 0x7fb090e0eb70>, <KeyPoint 0x7fb090...
# isle-of-jura-single-malt-scotch-whisky-10-year-...  [<KeyPoint 0x7fb0910383f0>, <KeyPoint 0x7fb091...
# boondocks-8-year-[size].png                         [<KeyPoint 0x7fb0911efc30>, <KeyPoint 0x7fb091...
# SMIRNOFF_NO._21_RED_VODKA_80PF_750ML.png            [<KeyPoint 0x7fb09140c4b0>, <KeyPoint 0x7fb091...
# redbreast-irish-whiskey-12-year.png                 [<KeyPoint 0x7fb0914e0cf0>, <KeyPoint 0x7fb091...
# pierre-ferrand-selection-des-anges-[size].png       [<KeyPoint 0x7fb0915d3570>, <KeyPoint 0x7fb091...
# Glenfarclas-25.png                                  [<KeyPoint 0x7fb09154edb0>, <KeyPoint 0x7fb091...
# jim-beam-rye-[size].png                             [<KeyPoint 0x7fb09150a630>, <KeyPoint 0x7fb091...
# ...                                                                                               ...
# tomatin-12-year-french-oak-single-malt-[size].png   [<KeyPoint 0x7fb0870a2330>, <KeyPoint 0x7fb087...
# bodegas-tradicion-brandy-de-jerez-solera-gran-r...  [<KeyPoint 0x7fb08705db70>, <KeyPoint 0x7fb087...
# el-tesoro-80th-anniversary-extra-anejo-[size].png   [<KeyPoint 0x7fb087016fc0>, <KeyPoint 0x7fb087...
# jack-daniels-gentleman-jack-[size].png              [<KeyPoint 0x7fb086fd2840>, <KeyPoint 0x7fb086...
# dalmore-port-wood-reserve-[size].png                [<KeyPoint 0x7fb086f8e0c0>, <KeyPoint 0x7fb086...
# ciroc-vs-brandy-[size].png                          [<KeyPoint 0x7fb086f49900>, <KeyPoint 0x7fb086...
# johnnie-walker-18-year-[size].png                   [<KeyPoint 0x7fb086f77810>, <KeyPoint 0x7fb086...
# hillrock-estate-distillery-solera-aged-bourbon-...  [<KeyPoint 0x7fb086f33090>, <KeyPoint 0x7fb086...
# kings-county-bottled-in-bond-[size].png             [<KeyPoint 0x7fb086eee8d0>, <KeyPoint 0x7fb086...
# Highland Park 25 Year Old.png                       [<KeyPoint 0x7fb086eaa150>, <KeyPoint 0x7fb086...
# wild-turkey-single-barrel-kentucky-spirit-[size...  [<KeyPoint 0x7fb086e65990>, <KeyPoint 0x7fb086...
# michters-us-1-rye-[size].png                        [<KeyPoint 0x7fb086e21210>, <KeyPoint 0x7fb086...
# jeffersons-pritchard-hill-[size].png                [<KeyPoint 0x7fb086ddca50>, <KeyPoint 0x7fb086...
# old-grand-dad-bourbon-[size].png                    [<KeyPoint 0x7fb086d992d0>, <KeyPoint 0x7fb086...
# Hardy Organic VSOP Cognac.png                       [<KeyPoint 0x7fb086d55b10>, <KeyPoint 0x7fb086...
# los-nahuales-anejo-[size].png                       [<KeyPoint 0x7fb086d102a0>, <KeyPoint 0x7fb086...
# woodford-reserve-master-s-collection-oat-grain-...  [<KeyPoint 0x7fb086ccbae0>, <KeyPoint 0x7fb086...
# pierre-ferrand-ancestrale-[size].png                [<KeyPoint 0x7fb086c872d0>, <KeyPoint 0x7fb086...
# johnnie-walker-green-label-[size].png               [<KeyPoint 0x7fb086c42b10>, <KeyPoint 0x7fb086...
# deanston-14-years-limited-release-[size].png        [<KeyPoint 0x7fb086bfe390>, <KeyPoint 0x7fb086...
# arette-gran-clase-extra-anejo-[size].png            [<KeyPoint 0x7fb086c37240>, <KeyPoint 0x7fb086...
# four-roses-small-batch-select-[size].png            [<KeyPoint 0x7fb086bf2a80>, <KeyPoint 0x7fb086...
# omar-single-malt-bourbon-cask-[size].png            [<KeyPoint 0x7fb086bae300>, <KeyPoint 0x7fb086...
# isle-of-jura-seven-woods-[size].png                 [<KeyPoint 0x7fb086b69b40>, <KeyPoint 0x7fb086...
# rebel-yell-single-barrel-[size].png                 [<KeyPoint 0x7fb086b253c0>, <KeyPoint 0x7fb086...
# crown-royal-blenders-mash-[size].png                [<KeyPoint 0x7fb086ae0c00>, <KeyPoint 0x7fb086...
# prunier-family-reserve-[size].png                   [<KeyPoint 0x7fb086a9c480>, <KeyPoint 0x7fb086...
# hine-h-by-hine-fine-champagne-[size].png            [<KeyPoint 0x7fb086a57a80>, <KeyPoint 0x7fb086...
# don-julio-blanco-tequila-[size].png                 [<KeyPoint 0x7fb086a12090>, <KeyPoint 0x7fb086...
# clement-6-year-[size].png                           [<KeyPoint 0x7fb0869cd8d0>, <KeyPoint 0x7fb086...
#
# [754 rows x 2 columns]

# %%
def query(image):
    img = cv2.imread(image, cv2.IMREAD_UNCHANGED)
    keypoints, desc = orb.detectAndCompute(img, None)
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    spirits_db[f"matches_{image}"] = spirits_db["descriptor"].apply(lambda x: bf.match(desc, x))
    spirits_db[f"closest_{image}"] = spirits_db[f"matches_{image}"].apply(get_distance_sum)
    closest = spirits_db[spirits_db[f"closest_{image}"] == spirits_db[f"closest_{image}"].min()]
    return closest.index[0]

def get_distance_sum(match):
    dist = 0
    match = sorted(match, key=lambda x: x.distance)
    for m in match[:100]:
        dist += m.distance
    return dist

for image in os.listdir("queryImages/"):
    if image.endswith(".jpg") or image.endswith(".png"):
        img = cv2.imread(f"queryImages/{image}", cv2.IMREAD_GRAYSCALE)
        print(image, "------", query(f"queryImages/{image}"))
# Out:
# 10 copy.jpg ------ colkegan-single-malt-[size].png
# 10.jpg ------ Barrell Bourbon Batch 016-750ml.png
# 0 copy.jpg ------ Ad-Laws-bottled-in-bond.png
# 0.jpg ------ Ad-Laws-bottled-in-bond.png
# 7.jpg ------ bache-gabrielsen-american-oak-cognac-[size].png
# 12.jpg ------ bache-gabrielsen-american-oak-cognac-[size].png
# 7 copy.jpg ------ bache-gabrielsen-american-oak-cognac-[size].png
# 1.jpg ------ caol-ila-12-year-[size].png
# 2.jpg ------ Ad-Laws-bottled-in-bond.png
# 19.jpg ------ Barrell Bourbon Batch 016-750ml.png
# 54.jpg ------ tesseron-lot-76-xo-cognac-[size].png
